# %%
import matplotlib.pyplot as plt
import numpy as numpy
import pandas as pd
import seaborn as sns
import os
import cv2
from PIL import Image
from scipy.spatial import distance
import face_recognition
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Highlight Facial details in the image

# %%
img_path = r"C:\Users\shubh\Downloads\archive\Driver Drowsiness Dataset (DDD)\Drowsy\A0001.png"
image = Image.open(img_path)
plt.axis("off")
plt.imshow(image)

# %%
def mapping_features(img_path):
    image_bgr = cv2.imread(img_path)
    image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

    face_locations = face_recognition.face_locations(image_rgb, model='cnn')
    for face_location in face_locations:
        landmarks = face_recognition.face_landmarks(image_rgb, [face_location])[0]
        for landmark_type, landmark_points in landmarks.items():
            for (x, y) in landmark_points:
                cv2.circle(image_rgb, (x, y), 3, (0, 255, 0), 2)

    plt.figure(figsize=(6, 6))
    plt.show(image_rgb)
    plt.axis('off')
    plt.show()


mapping_features(img_path)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 18
#      14     plt.axis('off')
#      15     plt.show()
# ---> 18 mapping_features(img_path)
#
# Cell In[17], line 5, in mapping_features(img_path)
#       2 image_bgr = cv2.imread(img_path)
#       3 image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
# ----> 5 face_locations = face_recognition.face_locations(image_rgb, model='cnn')
#       6 for face_location in face_locations:
#       7     landmarks = face_recognition.face_landmarks(image_rgb, [face_location])[0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\face_recognition\api.py:119, in face_locations(img, number_of_times_to_upsample, model)
#     109 """
#     110 Returns an array of bounding boxes of human faces in a image
#     111
#    (...)
# ...

# %%
def eye_blink_detection(wdg_cntr, total_thres):
    # wdg_cntr: Watchdog counter for closed eye detection.
    # total_thres: Multiple threshold hits.

    return 0

# %%
def trip_time():
    return 0
